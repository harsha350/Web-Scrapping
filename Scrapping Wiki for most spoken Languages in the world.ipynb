# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from tabulate import tabulate

class Regions():
    """docstring for ClassName"""

    def __init__(self):
        self.number = ""
        self.name = ""
#         weather = {'name': self.number, 'link': self.name}


Driver = webdriver.Chrome(executable_path="C:\Chromedriver_win32\chromedriver.exe")

Driver.get("https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers")

DB = Driver.page_source

soup = BeautifulSoup(DB, 'lxml')

div = soup.find('table', class_="wikitable sortable jquery-tablesorter")
df = pd.read_html(str(div))
print(tabulate(df[0], headers='keys', tablefmt='plain'))

Driver.close()
# Out:
#      Rank    Language                                 Nativespeakersin millions2007 (2010)    Percentageof worldpopulation(2007)
#   0  1       Mandarin (entire branch)                 935 (955)                               14.1%
#   1  2       Spanish                                  390 (405)                               5.85%
#   2  3       English                                  365 (360)                               5.52%
#   3  4       Hindi[a]                                 295 (310)                               4.46%
#   4  5       Arabic                                   280 (295)                               4.23%
#   5  6       Portuguese                               205 (215)                               3.08%
#   6  7       Bengali (Bangla)                         200 (205)                               3.05%
#   7  8       Russian                                  160 (155)                               2.42%
# ...
